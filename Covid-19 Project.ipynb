# %% [markdown]
# COVID-19 PROJECT ON VISUALIZATION

# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt
df = pd.read_csv(r"C:\Users\Dell E7470\Desktop\covid_19.csv")
df
# Out:
#               country      continent   population         day  \
# 0        Saint-Helena         Africa       6115.0  2024-06-30
# 1    Falkland-Islands  South-America       3539.0  2024-06-30
# 2          Montserrat  North-America       4965.0  2024-06-30
# 3    Diamond-Princess            NaN          NaN  2024-06-30
# 4        Vatican-City         Europe        799.0  2024-06-30
# ..                ...            ...          ...         ...
# 233         Argentina  South-America   46010234.0  2024-06-30
# 234       Netherlands         Europe   17211447.0  2024-06-30
# 235            Mexico  North-America  131562772.0  2024-06-30
# 236              Iran           Asia   86022837.0  2024-06-30
# 237         Indonesia           Asia  279134505.0  2024-06-30
#
#                           time     Cases  Recovered    Deaths        Tests
# 0    2024-06-30T16:15:16+00:00      2166        2.0       NaN          NaN
# ...

# %%
print(plt.style.available)
plt.style.use('seaborn-v0_8-talk')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
df.drop_duplicates()
df
# Out:
#               country      continent   population         day  \
# 0        Saint-Helena         Africa       6115.0  2024-06-30
# 1    Falkland-Islands  South-America       3539.0  2024-06-30
# 2          Montserrat  North-America       4965.0  2024-06-30
# 3    Diamond-Princess            NaN          NaN  2024-06-30
# 4        Vatican-City         Europe        799.0  2024-06-30
# ..                ...            ...          ...         ...
# 233         Argentina  South-America   46010234.0  2024-06-30
# 234       Netherlands         Europe   17211447.0  2024-06-30
# 235            Mexico  North-America  131562772.0  2024-06-30
# 236              Iran           Asia   86022837.0  2024-06-30
# 237         Indonesia           Asia  279134505.0  2024-06-30
#
#                           time     Cases  Recovered    Deaths        Tests
# 0    2024-06-30T16:15:16+00:00      2166        2.0       NaN          NaN
# ...

# %%
df= df.drop(columns= "time")
df
# Out:
#               country      continent   population         day     Cases  \
# 0        Saint-Helena         Africa       6115.0  2024-06-30      2166
# 1    Falkland-Islands  South-America       3539.0  2024-06-30      1930
# 2          Montserrat  North-America       4965.0  2024-06-30      1403
# 3    Diamond-Princess            NaN          NaN  2024-06-30       712
# 4        Vatican-City         Europe        799.0  2024-06-30        29
# ..                ...            ...          ...         ...       ...
# 233         Argentina  South-America   46010234.0  2024-06-30  10128845
# 234       Netherlands         Europe   17211447.0  2024-06-30   8635786
# 235            Mexico  North-America  131562772.0  2024-06-30   7702809
# 236              Iran           Asia   86022837.0  2024-06-30   7627186
# 237         Indonesia           Asia  279134505.0  2024-06-30   6829221
#
#      Recovered    Deaths        Tests
# 0          2.0       NaN          NaN
# ...

# %%
df= df.fillna("")
df
# Out:
#               country      continent   population         day     Cases  \
# 0        Saint-Helena         Africa       6115.0  2024-06-30      2166
# 1    Falkland-Islands  South-America       3539.0  2024-06-30      1930
# 2          Montserrat  North-America       4965.0  2024-06-30      1403
# 3    Diamond-Princess                              2024-06-30       712
# 4        Vatican-City         Europe        799.0  2024-06-30        29
# ..                ...            ...          ...         ...       ...
# 233         Argentina  South-America   46010234.0  2024-06-30  10128845
# 234       Netherlands         Europe   17211447.0  2024-06-30   8635786
# 235            Mexico  North-America  131562772.0  2024-06-30   7702809
# 236              Iran           Asia   86022837.0  2024-06-30   7627186
# 237         Indonesia           Asia  279134505.0  2024-06-30   6829221
#
#      Recovered    Deaths        Tests
# 0          2.0
# 1       1930.0                 8632.0
# ...

# %%
df2 =df.set_index('country')
df2
# Out:
#                       continent   population         day     Cases  Recovered  \
# country
# Saint-Helena             Africa       6115.0  2024-06-30      2166        2.0
# Falkland-Islands  South-America       3539.0  2024-06-30      1930     1930.0
# Montserrat        North-America       4965.0  2024-06-30      1403     1376.0
# Diamond-Princess                              2024-06-30       712      699.0
# Vatican-City             Europe        799.0  2024-06-30        29       29.0
# ...                         ...          ...         ...       ...        ...
# Argentina         South-America   46010234.0  2024-06-30  10128845  9997258.0
# Netherlands              Europe   17211447.0  2024-06-30   8635786  8612599.0
# Mexico            North-America  131562772.0  2024-06-30   7702809  6899865.0
# Iran                       Asia   86022837.0  2024-06-30   7627186
# Indonesia                  Asia  279134505.0  2024-06-30   6829221  6647104.0
#
# ...

# %%
df2=df2.filter(items= [ 'Cases', 'Deaths', 'Recovered'])
df2
# Out:
#                      Cases    Deaths  Recovered
# country
# Saint-Helena          2166                  2.0
# Falkland-Islands      1930               1930.0
# Montserrat            1403       8.0     1376.0
# Diamond-Princess       712      13.0      699.0
# Vatican-City            29                 29.0
# ...                    ...       ...        ...
# Argentina         10128845  130841.0  9997258.0
# Netherlands        8635786   22992.0  8612599.0
# Mexico             7702809  334958.0  6899865.0
# Iran               7627186  146811.0
# Indonesia          6829221  162063.0  6647104.0
#
# [238 rows x 3 columns]

# %%
df2
# Out:
#                      Cases    Deaths  Recovered
# country
# Saint-Helena          2166                  2.0
# Falkland-Islands      1930               1930.0
# Montserrat            1403       8.0     1376.0
# Diamond-Princess       712      13.0      699.0
# Vatican-City            29                 29.0
# ...                    ...       ...        ...
# Argentina         10128845  130841.0  9997258.0
# Netherlands        8635786   22992.0  8612599.0
# Mexico             7702809  334958.0  6899865.0
# Iran               7627186  146811.0
# Indonesia          6829221  162063.0  6647104.0
#
# [238 rows x 3 columns]

# %%
df2=df2.sort_values(by= "Cases", ascending= False). head(6)
df2
# Out:
#                    Cases     Deaths    Recovered
# country
# All            704753890  7010681.0  675619811.0
# Europe         253406198  2101824.0  248754104.0
# Asia           221500265  1553662.0  205673091.0
# North-America  131889132  1695941.0  127665129.0
# USA            111820082  1219487.0  109814428.0
# South-America   70200879  1367332.0   66683585.0

# %%
df2.groupby('country')
df2
# Out:
#                    Cases     Deaths    Recovered
# country
# All            704753890  7010681.0  675619811.0
# Europe         253406198  2101824.0  248754104.0
# Asia           221500265  1553662.0  205673091.0
# North-America  131889132  1695941.0  127665129.0
# USA            111820082  1219487.0  109814428.0
# South-America   70200879  1367332.0   66683585.0

# %%
df2.plot()
# Out:
# <Axes: xlabel='country'>

# %%
df2.plot(kind= 'line')
# Out:
# <Axes: xlabel='country'>

# %%
df2.plot(kind = 'line', subplots = True)
# Out:
# array([<Axes: xlabel='country'>, <Axes: xlabel='country'>,
#        <Axes: xlabel='country'>], dtype=object)

# %%
df2.plot(kind = 'line', title= 'Covid-19 Rating')
# Out:
# <Axes: title={'center': 'Covid-19 Rating'}, xlabel='country'>

# %%
df2.plot(kind = 'line', title= 'Covid-19 Rating', xlabel= 'country',ylabel= 'Scores',)
# Out:
# <Axes: title={'center': 'Covid-19 Rating'}, xlabel='country', ylabel='Scores'>

# %%
df2.plot(kind= 'bar')
# Out:
# <Axes: xlabel='country'>

# %%
df2.plot(kind = 'bar', title= 'Covid-19 Rating', xlabel= 'country',ylabel= 'Scores',)
# Out:
# <Axes: title={'center': 'Covid-19 Rating'}, xlabel='country', ylabel='Scores'>

# %%
df2.plot.barh(stacked= True)
# Out:
# <Axes: ylabel='country'>

# %%
df2['Cases'].plot(kind = 'bar',title= 'Covid-19 Rating', xlabel= 'country',ylabel= 'Scores')
# Out:
# <Axes: title={'center': 'Covid-19 Rating'}, xlabel='country', ylabel='Scores'>

# %%
df2['Deaths'].plot(kind = 'bar',title= 'Covid-19 Rating', xlabel= 'country',ylabel= 'Scores')
# Out:
# <Axes: title={'center': 'Covid-19 Rating'}, xlabel='country', ylabel='Scores'>

# %%
df2['Recovered'].plot(kind = 'bar',title= 'Covid-19 Rating', xlabel= 'country',ylabel= 'Scores')
# Out:
# <Axes: title={'center': 'Covid-19 Rating'}, xlabel='country', ylabel='Scores'>

# %%
df2.plot.area()
# Out:
# <Axes: xlabel='country'>

# %%
df2.plot.pie(y = 'Cases', title = 'Covid-19 Rating')
# Out:
# <Axes: title={'center': 'Covid-19 Rating'}, ylabel='Cases'>

# %%
df2.plot.pie(y = 'Deaths', title = 'Covid-19 Rating')
# Out:
# <Axes: title={'center': 'Covid-19 Rating'}, ylabel='Deaths'>

# %%
df2.plot.pie(y = 'Recovered', title = 'Covid-19 Rating')
# Out:
# <Axes: title={'center': 'Covid-19 Rating'}, ylabel='Recovered'>

# %%
df2.plot.scatter(x= 'Cases', y= 'Deaths', s= 100)
# Out:
# <Axes: xlabel='Cases', ylabel='Deaths'>

# %%
df2.boxplot()
# Out:
# <Axes: >
